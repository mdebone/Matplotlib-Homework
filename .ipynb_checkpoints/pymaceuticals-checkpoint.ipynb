# %% [markdown]
# ### Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
from scipy.stats import linregress

# %%
# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
mouse_metadata = pd.read_csv(mouse_metadata_path)
mouse_metadata
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)
# 0       k403     Ramicane    Male          21          16
# 1       s185    Capomulin  Female           3          17
# 2       x401    Capomulin  Female          16          15
# 3       m601    Capomulin    Male          22          17
# 4       g791     Ramicane    Male          11          16
# ..       ...          ...     ...         ...         ...
# 244     z314     Stelasyn  Female          21          28
# 245     z435     Propriva  Female          12          26
# 246     z581    Infubinol  Female          24          25
# 247     z795     Naftisol  Female          13          29
# 248     z969     Naftisol    Male           9          30
#
# [249 rows x 5 columns]

# %%
# Read the mouse data and the study results
study_results_path = "data/Study_results.csv"
study_results = pd.read_csv(study_results_path)
study_results
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0        b128          0           45.000000                 0
# 1        f932          0           45.000000                 0
# 2        g107          0           45.000000                 0
# 3        a457          0           45.000000                 0
# 4        c819          0           45.000000                 0
# ...       ...        ...                 ...               ...
# 1888     r944         45           41.581521                 2
# 1889     u364         45           31.023923                 3
# 1890     p438         45           61.433892                 1
# 1891     x773         45           58.634971                 4
# 1892     b879         45           72.555239                 2
#
# [1893 rows x 4 columns]

# %%
# Combine the data into a single dataset
# Display the data table for preview
combined_mice = pd.merge(study_results, mouse_metadata, how="outer", on="Mouse ID")
combined_mice
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# 0     Female           9          22
# 1     Female           9          22
# 2     Female           9          22
# 3     Female           9          22
# 4     Female           9          22
# ...      ...         ...         ...
# 1888    Male          22          17
# 1889    Male          22          17
# 1890    Male          22          17
# 1891    Male          22          17
# 1892    Male          22          17
#
# [1893 rows x 8 columns]

# %%
# Checking the number of mice.
mice_count = combined_mice.groupby(['Mouse ID'])
mice_count.head()
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1883     m601          0           45.000000                 0    Capomulin
# 1884     m601          5           41.408591                 1    Capomulin
# 1885     m601         10           36.825367                 1    Capomulin
# 1886     m601         15           35.464612                 1    Capomulin
# 1887     m601         20           34.255732                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# 0     Female           9          22
# 1     Female           9          22
# 2     Female           9          22
# 3     Female           9          22
# 4     Female           9          22
# ...      ...         ...         ...
# 1883    Male          22          17
# 1884    Male          22          17
# 1885    Male          22          17
# 1886    Male          22          17
# 1887    Male          22          17
#
# [1108 rows x 8 columns]

# %%
# Optional: Get all the data for the duplicate mouse ID. 
mice_count_index = combined_mice.set_index(['Mouse ID', 'Timepoint'])
mice_count_index
# Out:
#                     Tumor Volume (mm3)  Metastatic Sites Drug Regimen     Sex  \
# Mouse ID Timepoint
# b128     0                   45.000000                 0    Capomulin  Female
#          5                   45.651331                 0    Capomulin  Female
#          10                  43.270852                 0    Capomulin  Female
#          15                  43.784893                 0    Capomulin  Female
#          20                  42.731552                 0    Capomulin  Female
# ...                                ...               ...          ...     ...
# m601     25                  33.118756                 1    Capomulin    Male
#          30                  31.758275                 1    Capomulin    Male
#          35                  30.834357                 1    Capomulin    Male
#          40                  31.378045                 1    Capomulin    Male
#          45                  28.430964                 1    Capomulin    Male
#
#                     Age_months  Weight (g)
# Mouse ID Timepoint
# b128     0                   9          22
#          5                   9          22
#          10                  9          22
#          15                  9          22
#          20                  9          22
# ...                        ...         ...
# m601     25                 22          17
#          30                 22          17
#          35                 22          17
#          40                 22          17
#          45                 22          17
#
# [1893 rows x 6 columns]

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df = combined_mice.drop_duplicates(subset='Mouse ID', keep='last')
clean_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 9        b128         45           38.982878                 2    Capomulin
# 10       f932          0           45.000000                 0     Ketapril
# 18       g107         35           71.905117                 0     Ketapril
# 21       a457         10           49.783419                 0     Ketapril
# 30       c819         40           62.175705                 1     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1857     t565         45           34.455298                 0    Capomulin
# 1867     i557         45           47.685963                 1    Capomulin
# 1877     m957         45           33.329098                 1    Capomulin
# 1882     f966         20           30.485985                 0    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# 9     Female           9          22
# 10      Male          15          29
# 18    Female           2          29
# 21    Female          11          30
# 30      Male          21          25
# ...      ...         ...         ...
# 1857  Female          20          17
# 1867  Female           1          24
# 1877  Female           3          19
# 1882    Male          16          17
# 1892    Male          22          17
#
# [249 rows x 8 columns]

# %%
# Checking the number of mice in the clean DataFrame.
print(clean_df.value_counts('Mouse ID'))
# Out:
# Mouse ID
# z969    1
# i177    1
# j365    1
# j296    1
# j246    1
#        ..
# q633    1
# q610    1
# q597    1
# q582    1
# a203    1
# Length: 249, dtype: int64

# %% [markdown]
# ### Summary Statistics

# %%
# See how many treatment groups there are
#count_treatment = treatment_group.count()
#count_treatment

# %%
# generate a summary statics table of mean, median, variance, standard deviation and SEM of the tumor volume for each regimen

tumor_mean = combined_mice.groupby('Drug Regimen')['Tumor Volume (mm3)'].mean()
tumor_median = combined_mice.groupby('Drug Regimen')['Tumor Volume (mm3)'].median()
tumor_std =  combined_mice.groupby('Drug Regimen')['Tumor Volume (mm3)'].std()
tumor_var = combined_mice.groupby('Drug Regimen')['Tumor Volume (mm3)'].var()
tumor_sem = combined_mice.groupby('Drug Regimen')['Tumor Volume (mm3)'].sem()

# %%
# Get the summary statistics of the mice
treatment_stats_df = pd.DataFrame({'Mean':tumor_mean,
                                  'Median':tumor_median,
                                   'Standard Deviation':tumor_std,
                                   'Variance':tumor_var,
                                  'Error of Mean':tumor_sem})

treatment_stats_df
# Out:
#                    Mean     Median  Standard Deviation   Variance  \
# Drug Regimen
# Capomulin     40.675741  41.557809            4.994774  24.947764
# Ceftamin      52.591172  51.776157            6.268188  39.290177
# Infubinol     52.884795  51.820584            6.567243  43.128684
# Ketapril      55.235638  53.698743            8.279709  68.553577
# Naftisol      54.331565  52.509285            8.134708  66.173479
# Placebo       54.033581  52.288934            7.821003  61.168083
# Propriva      52.322552  50.854632            6.507770  42.351070
# Ramicane      40.216745  40.673236            4.846308  23.486704
# Stelasyn      54.233149  52.431737            7.710419  59.450562
# Zoniferol     53.236507  51.818479            6.966589  48.533355
#
#               Error of Mean
# Drug Regimen
# Capomulin          0.329346
# Ceftamin           0.469821
# Infubinol          0.492236
# Ketapril           0.603860
# Naftisol           0.596466
# Placebo            0.581331
# Propriva           0.512884
# Ramicane           0.320955
# Stelasyn           0.573111
# Zoniferol          0.516398

# %% [markdown]
# ### Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
pandas_bar = combined_mice['Drug Regimen'].value_counts().plot.bar()
pandas_bar.set_title("Total number of Timepoints for each Tested Drug Regimen")
pandas_bar.set_xlabel("Drug Regimen")
pandas_bar.set_ylabel("Number of Timepoints")
# Out:
# Text(0, 0.5, 'Number of Timepoints')

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.
values = combined_mice['Drug Regimen'].value_counts()
x_axis = np.arange(len(values))
plt.bar(x_axis, values)
tick_loc = [value for value in x_axis]
plt.xticks(tick_loc, values.index.values)
plt.xticks(rotation=45)

# Set the labels for the chart
plt.title("Total Number of Timepoints for each Tested Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Timepoints")
          
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
pandas_pie = combined_mice['Sex'].value_counts().plot.pie(autopct="%1.1f%%", startangle=90)
pandas_pie.set_title("Distribution of Female versus Male Mice")
pandas_pie.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
sexes = combined_mice['Sex'].value_counts()
plt.pie(sexes, labels=sexes.index.values, autopct="%1.1f%%", startangle=90)
plt.title("Distribution of Female versus Male Mice")
plt.show()

# %% [markdown]
# ### Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
# Create empty list to fill with tumor volume data (for plotting)

# %%
Capomulin_df = clean_df[clean_df['Drug Regimen']=="Capomulin"]
Capomulin_df.head()
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 9        b128         45           38.982878                 2    Capomulin
# 1680     j246         35           38.753265                 1    Capomulin
# 1690     r554         45           32.377357                 3    Capomulin
# 1700     s185         45           23.343598                 1    Capomulin
# 1710     b742         45           38.939633                 0    Capomulin
#
#          Sex  Age_months  Weight (g)
# 9     Female           9          22
# 1680  Female          21          21
# 1690  Female           8          17
# 1700  Female           3          17
# 1710    Male           7          21

# %%
# Ramicane_df = clean_[clean_df['Drug Regimen']=="Ramicane"].copy()
# Ramicane_df = Ramicane_df.set_index('Mouse ID')
# Ramicane_df.head()

# %%
# Infubinol_df = clean_df[clean_df['Drug Regimen']=="Infubinol"].copy()
# Infubinol_df = Infubinol_df.set_index('Mouse ID')
# Infubinol_df.head()

# %%
# Ceftamin_df = clean_df[clean_df['Drug Regimen']=="Ceftamin"].copy()
# Ceftamin_df = Ceftamin_df.set_index('Mouse ID')
# Ceftamin_df.head()

# %%
# Start by getting the last (greatest) timepoint for each mouse
treatment_group_df = pd.DataFrame(combined_mice.groupby('Mouse ID')['Timepoint'].max().sort_values()).reset_index().rename(columns={'Timepoint': 'Last Timepoint'})
treatment_group_df

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
combined_group_df = pd.merge(combined_mice,treatment_group_df, on='Mouse ID')
combined_group_df.head()
#combined_group_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)  Last Timepoint
# 0     Female           9          22              45
# 1     Female           9          22              45
# 2     Female           9          22              45
# 3     Female           9          22              45
# 4     Female           9          22              45
# ...      ...         ...         ...             ...
# 1888    Male          22          17              45
# 1889    Male          22          17              45
# 1890    Male          22          17              45
# 1891    Male          22          17              45
# 1892    Male          22          17              45
#
# [1893 rows x 9 columns]

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']
tumor_vol = []

for treatment in treatments:
    
    temp_df = combined_group_df.loc[combined_group_df['Drug Regimen']==treatment]
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    volume_df = temp_df.loc[temp_df['Timepoint'] == temp_df['Last Timepoint']]
    
    volumes = temp_df['Tumor Volume (mm3)']
    tumor_vol.append(volumes)
    
    quartiles = volumes.quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq

    # Calculate the IQR and quantitatively determine if there are any potential outliers. 
    print(f"The lower quartile of {treatment}'s volumes is: {lowerq}")
    print(f"The upper quartile of {treatment}'s volumes is: {upperq}")
    print(f"The interquartile range of {treatment}'s volumes is: {iqr}")
    print(f"The the median of {treatment}'s volumes is: {quartiles[0.5]} ")
    
    
    
    # Determine outliers using upper and lower bounds
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    print(f"Values of {treatment} below {lower_bound} could be outliers.")
    print(f"Values of {treatment} above {upper_bound} could be outliers.")
    print("-"*40)
# Out:
# The lower quartile of Capomulin's volumes is: 37.685932865
# The upper quartile of Capomulin's volumes is: 45.0
# The interquartile range of Capomulin's volumes is: 7.314067135000002
# The the median of Capomulin's volumes is: 41.557808879999996
# Values of Capomulin below 26.714832162499995 could be outliers.
# Values of Capomulin above 55.9711007025 could be outliers.
# ----------------------------------------
# The lower quartile of Ramicane's volumes is: 36.67463458499999
# The upper quartile of Ramicane's volumes is: 45.0
# The interquartile range of Ramicane's volumes is: 8.325365415000007
# The the median of Ramicane's volumes is: 40.67323554
# Values of Ramicane below 24.18658646249998 could be outliers.
# Values of Ramicane above 57.48804812250001 could be outliers.
# ----------------------------------------
# The lower quartile of Infubinol's volumes is: 47.3123533
# The upper quartile of Infubinol's volumes is: 57.314443967500004
# The interquartile range of Infubinol's volumes is: 10.002090667500006
# The the median of Infubinol's volumes is: 51.82058438
# Values of Infubinol below 32.309217298749985 could be outliers.
# Values of Infubinol above 72.31757996875001 could be outliers.
# ----------------------------------------
# The lower quartile of Ceftamin's volumes is: 47.208427112500004
# The upper quartile of Ceftamin's volumes is: 56.801437570000004
# The interquartile range of Ceftamin's volumes is: 9.5930104575
# The the median of Ceftamin's volumes is: 51.77615728000001
# Values of Ceftamin below 32.818911426250004 could be outliers.
# Values of Ceftamin above 71.19095325625 could be outliers.
# ----------------------------------------

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
plt.boxplot(tumor_vol)
plt.title('Final Tumor Volume (mm3) by Drug Regimen')
plt.ylabel('Tumor Volume (mm3)')

plt.xticks([1,2,3,4,], ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'])

#plt.grid()
plt.show()

# %% [markdown]
# ### Line and Scatter Plots

# %%
Capomulin_dataf = combined_group_df[combined_group_df['Drug Regimen']=="Capomulin"]
Capomulin_dataf.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0           45.000000                 0    Capomulin
# 1     b128          5           45.651331                 0    Capomulin
# 2     b128         10           43.270852                 0    Capomulin
# 3     b128         15           43.784893                 0    Capomulin
# 4     b128         20           42.731552                 0    Capomulin
#
#       Sex  Age_months  Weight (g)  Last Timepoint
# 0  Female           9          22              45
# 1  Female           9          22              45
# 2  Female           9          22              45
# 3  Female           9          22              45
# 4  Female           9          22              45

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
mouse = Capomulin_dataf.loc[Capomulin_dataf['Mouse ID'] == 'm601']

plt.plot(mouse['Timepoint'], mouse['Tumor Volume (mm3)'], marker = 'o')

plt.title("m601's Capomulin treatment over Time")
plt.xlabel("Time (days)")
plt.ylabel("Tumor Volume (mm3)")

plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
Capomulin_scatter = combined_group_df[combined_group_df['Drug Regimen']=="Capomulin"]
Capomulin_scatter.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0           45.000000                 0    Capomulin
# 1     b128          5           45.651331                 0    Capomulin
# 2     b128         10           43.270852                 0    Capomulin
# 3     b128         15           43.784893                 0    Capomulin
# 4     b128         20           42.731552                 0    Capomulin
#
#       Sex  Age_months  Weight (g)  Last Timepoint
# 0  Female           9          22              45
# 1  Female           9          22              45
# 2  Female           9          22              45
# 3  Female           9          22              45
# 4  Female           9          22              45

# %%
# tumor volume average
tumor_volume_average = Capomulin_scatter.groupby('Mouse ID')['Tumor Volume (mm3)'].mean()

mouse_weight_average = Capomulin_scatter.groupby('Mouse ID')['Weight (g)'].mean()

# x = tumor_volume_average
# y = mouse_weight_average

plt.scatter(tumor_volume_average,mouse_weight_average)

plt.title('Average Tumor Volume by Weight')
plt.xlabel('Mean Tumor Volume (mm3)')
plt.ylabel('Mean Weight (g)')

plt.show()

# %% [markdown]
# ### Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
Capomulin_endpoints = Capomulin_scatter.drop_duplicates(subset='Mouse ID', keep='last')
Capomulin_endpoints.head()
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 9        b128         45           38.982878                 2    Capomulin
# 1680     j246         35           38.753265                 1    Capomulin
# 1690     r554         45           32.377357                 3    Capomulin
# 1700     s185         45           23.343598                 1    Capomulin
# 1710     b742         45           38.939633                 0    Capomulin
#
#          Sex  Age_months  Weight (g)  Last Timepoint
# 9     Female           9          22              45
# 1680  Female          21          21              35
# 1690  Female           8          17              45
# 1700  Female           3          17              45
# 1710    Male           7          21              45

# %%
# tumor volume average
tumor_volume_average = Capomulin_endpoints.groupby('Mouse ID')['Tumor Volume (mm3)'].mean()
mouse_weight_average = Capomulin_endpoints.groupby('Mouse ID')['Weight (g)'].mean()
correlation = st.pearsonr(tumor_volume_average,mouse_weight_average)
print(f"The correlation between average tumor volumes and mouse weights is {round(correlation[0],2)}")
# Out:
# The correlation between average tumor volumes and mouse weights is 0.88

# %%
x_values = tumor_volume_average
y_values = mouse_weight_average
plt.scatter(x_values,y_values)
correlation = st.pearsonr(x_values,y_values)
plt.xlabel('Mean Tumor Volume (mm3)')
plt.ylabel('Mean Weight (g)')
print(f"The correlation between average tumor volume and mouse weight is {round(correlation[0],2)}")
plt.show()
# Out:
# The correlation between average tumor volume and mouse weight is 0.88

# %%
y_values
# Out:
# Mouse ID
# b128    22
# b742    21
# f966    17
# g288    19
# g316    22
# i557    24
# i738    20
# j119    23
# j246    21
# l509    21
# l897    19
# m601    17
# m957    19
# r157    25
# r554    17
# r944    25
# s185    17
# s710    23
# t565    17
# u364    17
# v923    21
# w150    23
# w914    21
# x401    15
# y793    17
# Name: Weight (g), dtype: int64

# %%
# add the linear regression equation and line to plot
x_values = tumor_volume_average
y_values = mouse_weight_average
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2)) 
plt.scatter(x_values,y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (23,24),fontsize=15,color="red")
plt.xlabel('Mean Tumor Volume (mm3)')
plt.ylabel('Mean Weight (g)')
plt.show()
